# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', None)

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 12
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size

# %%
file = '../workproduct-files/cleaned-dataframes/t_dataMaster.pkl'
t_data = pd.read_pickle(file)

# %%
print(t_data.columns.values)
# Out:
# ['CONS_id' 'CONS_question' 'CONS_answer' 'CONS_alt answers'
#  'CONS_category' 'CONS_alt categories - NOT USED' 'CONS_type-formulation'
#  'CONS_type-multipleChoice' 'ORIG_id' 'ORIG_question' 'ORIG_answer'
#  'ORIG_alt answers' 'ORIG_category' 'ORIG_alt categories'
#  'ORIG_difficulty' 'ORIG_type' 'Source']

# %%
cats = t_data.groupby('CONS_category').count().sort_values(ascending = False, by = 'CONS_id')

fig, ax = plt.subplots(figsize=(15, 5))

x = np.arange(len(cats.index.values))

toPlot = ax.bar(x, height = cats['CONS_id'])

ax.set_xticklabels(cats.index)
ax.set_xticks(np.arange(len(cats.index.values)))

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
autolabel(toPlot)
        
fig.tight_layout()

plt.show()

# %%
types = t_data.groupby('CONS_type-formulation').count().sort_values(ascending = False, by = 'CONS_id')

fig, ax = plt.subplots(figsize=(15, 5))

x = np.arange(len(types.index.values))

toPlot = ax.bar(x, height = types['CONS_id'])

ax.set_xticklabels(types.index)
ax.set_xticks(np.arange(len(types.index.values)))

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
autolabel(toPlot)
        
fig.tight_layout()

plt.show()

# %%
multipleChoice = t_data.groupby('CONS_type-multipleChoice').count().sort_values(ascending = False, by = 'CONS_id')

fig, ax = plt.subplots(figsize=(15, 5))

x = np.arange(len(multipleChoice.index.values))

toPlot = ax.bar(x, height = multipleChoice['CONS_id'])

ax.set_xticklabels(multipleChoice.index)
ax.set_xticks(np.arange(len(multipleChoice.index.values)))

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
autolabel(toPlot)
        
fig.tight_layout()

plt.show()

# %%
source = t_data.groupby('Source').count().sort_values(ascending = False, by = 'CONS_id')

fig, ax = plt.subplots(figsize=(15, 5))

x = np.arange(len(source.index.values))

toPlot = ax.bar(x, height = source['CONS_id'])

ax.set_xticklabels(source.index)
ax.set_xticks(np.arange(len(source.index.values)))

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
autolabel(toPlot)
        
fig.tight_layout()

plt.show()
